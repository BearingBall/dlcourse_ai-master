# %% [markdown]
# # Задание 1.2 - Линейный классификатор (Linear classifier)
#
# В этом задании мы реализуем другую модель машинного обучения - линейный классификатор. Линейный классификатор подбирает для каждого класса веса, на которые нужно умножить значение каждого признака и потом сложить вместе.
# Тот класс, у которого эта сумма больше, и является предсказанием модели.
#
# В этом задании вы:
# - потренируетесь считать градиенты различных многомерных функций
# - реализуете подсчет градиентов через линейную модель и функцию потерь softmax
# - реализуете процесс тренировки линейного классификатора
# - подберете параметры тренировки на практике
#
# На всякий случай, еще раз ссылка на туториал по numpy:
# http://cs231n.github.io/python-numpy-tutorial/

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from dataset import load_svhn, random_split_train_val
from gradient_check import check_gradient
from metrics import multiclass_accuracy 
import linear_classifer

# %% [markdown]
# # Как всегда, первым делом загружаем данные
#
# Мы будем использовать все тот же SVHN.

# %%
def prepare_for_linear_classifier(train_X, test_X):
    train_flat = train_X.reshape(train_X.shape[0], -1).astype(np.float) / 255.0
    test_flat = test_X.reshape(test_X.shape[0], -1).astype(np.float) / 255.0
    
    # Subtract mean
    mean_image = np.mean(train_flat, axis = 0)
    train_flat -= mean_image
    test_flat -= mean_image
    
    # Add another channel with ones as a bias term
    train_flat_with_ones = np.hstack([train_flat, np.ones((train_X.shape[0], 1))])
    test_flat_with_ones = np.hstack([test_flat, np.ones((test_X.shape[0], 1))])    
    return train_flat_with_ones, test_flat_with_ones
    
train_X, train_y, test_X, test_y = load_svhn("data", max_train=10000, max_test=1000)    
train_X, test_X = prepare_for_linear_classifier(train_X, test_X)
# Split train into train and val
train_X, train_y, val_X, val_y = random_split_train_val(train_X, train_y, num_val = 1000)

# %% [markdown]
# # Играемся с градиентами!
#
# В этом курсе мы будем писать много функций, которые вычисляют градиенты аналитическим методом.
#
# Все функции, в которых мы будем вычислять градиенты, будут написаны по одной и той же схеме.
# Они будут получать на вход точку, где нужно вычислить значение и градиент функции, а на выходе будут выдавать кортеж (tuple) из двух значений - собственно значения функции в этой точке (всегда одно число) и аналитического значения градиента в той же точке (той же размерности, что и вход).
# ```
# def f(x):
#     """
#     Computes function and analytic gradient at x
#
#     x: np array of float, input to the function
#
#     Returns:
#     value: float, value of the function
#     grad: np array of float, same shape as x
#     """
#     ...
#
#     return value, grad
# ```
#
# Необходимым инструментом во время реализации кода, вычисляющего градиенты, является функция его проверки. Эта функция вычисляет градиент численным методом и сверяет результат с градиентом, вычисленным аналитическим методом.
#
# Мы начнем с того, чтобы реализовать вычисление численного градиента (numeric gradient) в функции `check_gradient` в `gradient_check.py`. Эта функция будет принимать на вход функции формата, заданного выше, использовать значение `value` для вычисления численного градиента и сравнит его с аналитическим - они должны сходиться.
#
# Напишите часть функции, которая вычисляет градиент с помощью численной производной для каждой координаты. Для вычисления производной используйте так называемую two-point formula (https://en.wikipedia.org/wiki/Numerical_differentiation):
#
# ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/22fc2c0a66c63560a349604f8b6b39221566236d)
#
# Все функции приведенные в следующей клетке должны проходить gradient check.

# %%
# TODO: Implement check_gradient function in gradient_check.py
# All the functions below should pass the gradient check

def square(x):
    return float(x*x), 2*x

check_gradient(square, np.array([3.0]))

def array_sum(x):
    assert x.shape == (2,), x.shape
    return np.sum(x), np.ones_like(x)

check_gradient(array_sum, np.array([3.0, 2.0]))

def array_2d_sum(x):
    assert x.shape == (2,2)
    return np.sum(x), np.ones_like(x)

check_gradient(array_2d_sum, np.array([[3.0, 2.0], [1.0, 0.0]]))
# Out:
# Gradient check passed!
# Gradient check passed!
# Gradient check passed!
# True

# %% [markdown]
# ## Начинаем писать свои функции, считающие аналитический градиент
#
# Теперь реализуем функцию softmax, которая получает на вход оценки для каждого класса и преобразует их в вероятности от 0 до 1:
# ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/e348290cf48ddbb6e9a6ef4e39363568b67c09d3)
#
# **Важно:** Практический аспект вычисления этой функции заключается в том, что в ней учавствует вычисление экспоненты от потенциально очень больших чисел - это может привести к очень большим значениям в числителе и знаменателе за пределами диапазона float.
#
# К счастью, у этой проблемы есть простое решение -- перед вычислением softmax вычесть из всех оценок максимальное значение среди всех оценок:
# ```
# predictions -= np.max(predictions)
# ```
# (подробнее здесь - http://cs231n.github.io/linear-classify/#softmax, секция `Practical issues: Numeric stability`)

# %%
# TODO Implement softmax and cross-entropy for single sample
probs = linear_classifer.softmax(np.array([-10, 0, 10]))

# Make sure it works for big numbers too!
probs = linear_classifer.softmax(np.array([1000, 0, 0]))
assert np.isclose(probs[0], 1.0)

# %% [markdown]
# Кроме этого, мы реализуем cross-entropy loss, которую мы будем использовать как функцию ошибки (error function).
# В общем виде cross-entropy определена следующим образом:
# ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/0cb6da032ab424eefdca0884cd4113fe578f4293)
#
# где x - все классы, p(x) - истинная вероятность принадлежности сэмпла классу x, а q(x) - вероятность принадлежности классу x, предсказанная моделью.
# В нашем случае сэмпл принадлежит только одному классу, индекс которого передается функции. Для него p(x) равна 1, а для остальных классов - 0.
#
# Это позволяет реализовать функцию проще!

# %%
probs = linear_classifer.softmax(np.array([-5, 0, 5]))
linear_classifer.cross_entropy_loss(probs, 1)
# Out:
# 5.006760443547122

# %% [markdown]
# После того как мы реализовали сами функции, мы можем реализовать градиент.
#
# Оказывается, что вычисление градиента становится гораздо проще, если объединить эти функции в одну, которая сначала вычисляет вероятности через softmax, а потом использует их для вычисления функции ошибки через cross-entropy loss.
#
# Эта функция `softmax_with_cross_entropy` будет возвращает и значение ошибки, и градиент по входным параметрам. Мы проверим корректность реализации с помощью `check_gradient`.

# %%
# TODO Implement combined function or softmax and cross entropy and produces gradient
loss, grad = linear_classifer.softmax_with_cross_entropy(np.array([1, 0, 0]), 1)
check_gradient(lambda x: linear_classifer.softmax_with_cross_entropy(x, 1), np.array([1, 0, 0], np.float))
# Out:
# Gradient check passed!
# True

# %% [markdown]
# В качестве метода тренировки мы будем использовать стохастический градиентный спуск (stochastic gradient descent или SGD), который работает с батчами сэмплов.
#
# Поэтому все наши фукнции будут получать не один пример, а батч, то есть входом будет не вектор из `num_classes` оценок, а матрица размерности `batch_size, num_classes`. Индекс примера в батче всегда будет первым измерением.
#
# Следующий шаг - переписать наши функции так, чтобы они поддерживали батчи.
#
# Финальное значение функции ошибки должно остаться числом, и оно равно среднему значению ошибки среди всех примеров в батче.

# %%
# TODO Extend combined function so it can receive a 2d array with batch of samples
np.random.seed(42)
# Test batch_size = 1
num_classes = 4
batch_size = 2
predictions = np.random.randint(-1, 3, size=(batch_size, num_classes)).astype(np.float)
target_index = np.random.randint(0, num_classes, size=(batch_size, 1)).astype(np.int)
check_gradient(lambda x: linear_classifer.softmax_with_cross_entropy(x, target_index), predictions)

# Test batch_size = 3
num_classes = 4
batch_size = 3
predictions = np.random.randint(-1, 3, size=(batch_size, num_classes)).astype(np.float)
target_index = np.random.randint(0, num_classes, size=(batch_size, 1)).astype(np.int)
check_gradient(lambda x: linear_classifer.softmax_with_cross_entropy(x, target_index), predictions)

# Make sure maximum subtraction for numberic stability is done separately for every sample in the batch
probs = linear_classifer.softmax(np.array([[20,0,0], [1000, 0, 0]]))
assert np.all(np.isclose(probs[:, 0], 1.0))
# Out:
# Gradients are different at (0, 0). Analytic: 0.10302, Numeric: 0.20603
# Gradients are different at (0, 0). Analytic: 0.08333, Numeric: 0.25000

# %% [markdown]
# ### Наконец, реализуем сам линейный классификатор!
#
# softmax и cross-entropy получают на вход оценки, которые выдает линейный классификатор.
#
# Он делает это очень просто: для каждого класса есть набор весов, на которые надо умножить пиксели картинки и сложить. Получившееся число и является оценкой класса, идущей на вход softmax.
#
# Таким образом, линейный классификатор можно представить как умножение вектора с пикселями на матрицу W размера `num_features, num_classes`. Такой подход легко расширяется на случай батча векторов с пикселями X размера `batch_size, num_features`:
#
# `predictions = X * W`, где `*` - матричное умножение.
#
# Реализуйте функцию подсчета линейного классификатора и градиентов по весам `linear_softmax` в файле `linear_classifer.py`

# %%
# TODO Implement linear_softmax function that uses softmax with cross-entropy for linear classifier
batch_size = 2
num_classes = 2
num_features = 3
np.random.seed(42)
W = np.random.randint(-1, 3, size=(num_features, num_classes)).astype(np.float)
X = np.random.randint(-1, 3, size=(batch_size, num_features)).astype(np.float)
target_index = np.ones(batch_size, dtype=np.int)

loss, dW = linear_classifer.linear_softmax(X, W, target_index)
check_gradient(lambda w: linear_classifer.linear_softmax(X, w, target_index), W)
# Out:
# Gradient check passed!
# True

# %% [markdown]
# ### И теперь регуляризация
#
# Мы будем использовать L2 regularization для весов как часть общей функции ошибки.
#
# Напомним, L2 regularization определяется как
#
# l2_reg_loss = regularization_strength * sum<sub>ij</sub> W[i, j]<sup>2</sup>
#
# Реализуйте функцию для его вычисления и вычисления соотвествующих градиентов.

# %%
# TODO Implement l2_regularization function that implements loss for L2 regularization
linear_classifer.l2_regularization(W, 0.01)
check_gradient(lambda w: linear_classifer.l2_regularization(w, 0.01), W)
# Out:
# Gradient check passed!
# True

# %% [markdown]
# # Тренировка!

# %% [markdown]
# Градиенты в порядке, реализуем процесс тренировки!

# %%
# TODO: Implement LinearSoftmaxClassifier.fit function
classifier = linear_classifer.LinearSoftmaxClassifier()
loss_history = classifier.fit(train_X, train_y, epochs=10, learning_rate=1e-3, batch_size=300, reg=1e1)
# Out:
# Epoch 0, loss: 2.397363
# Epoch 1, loss: 2.330354
# Epoch 2, loss: 2.311002
# Epoch 3, loss: 2.303897
# Epoch 4, loss: 2.303257
# Epoch 5, loss: 2.302898
# Epoch 6, loss: 2.302564
# Epoch 7, loss: 2.301815
# Epoch 8, loss: 2.301252
# Epoch 9, loss: 2.301256

# %%
# let's look at the loss history!
plt.plot(loss_history)

# %%
# Let's check how it performs on validation set
pred = classifier.predict(val_X)
accuracy = multiclass_accuracy(pred, val_y)
print("Accuracy: ", accuracy)

# Now, let's train more and see if it performs better
classifier.fit(train_X, train_y, epochs=100, learning_rate=1e-3, batch_size=300, reg=1e1)
pred = classifier.predict(val_X)
accuracy = multiclass_accuracy(pred, val_y)
print("Accuracy after training for 100 epochs: ", accuracy)
# Out:
# Accuracy:  0.127
# Epoch 0, loss: 2.301800
# Epoch 1, loss: 2.302558
# Epoch 2, loss: 2.302208
# Epoch 3, loss: 2.303309
# Epoch 4, loss: 2.302126
# Epoch 5, loss: 2.301524
# Epoch 6, loss: 2.301150
# Epoch 7, loss: 2.301359
# Epoch 8, loss: 2.302305
# Epoch 9, loss: 2.302205
# Epoch 10, loss: 2.301595
# Epoch 11, loss: 2.302039
# Epoch 12, loss: 2.301247
# Epoch 13, loss: 2.301836
# Epoch 14, loss: 2.302396
# Epoch 15, loss: 2.302299
# Epoch 16, loss: 2.301161
# Epoch 17, loss: 2.302058
# Epoch 18, loss: 2.302180
# Epoch 19, loss: 2.302339
# Epoch 20, loss: 2.302694
# Epoch 21, loss: 2.301872
# Epoch 22, loss: 2.302261
# Epoch 23, loss: 2.302209
# Epoch 24, loss: 2.302215
# Epoch 25, loss: 2.301591
# Epoch 26, loss: 2.301535
# Epoch 27, loss: 2.302557
# Epoch 28, loss: 2.301689
# Epoch 29, loss: 2.301815
# Epoch 30, loss: 2.301483
# Epoch 31, loss: 2.301553
# Epoch 32, loss: 2.301640
# Epoch 33, loss: 2.301991
# Epoch 34, loss: 2.302104
# Epoch 35, loss: 2.301741
# Epoch 36, loss: 2.302652
# Epoch 37, loss: 2.303017
# Epoch 38, loss: 2.301521
# Epoch 39, loss: 2.301504
# Epoch 40, loss: 2.301565
# Epoch 41, loss: 2.302361
# Epoch 42, loss: 2.302223
# Epoch 43, loss: 2.302385
# Epoch 44, loss: 2.302532
# Epoch 45, loss: 2.301950
# Epoch 46, loss: 2.301686
# Epoch 47, loss: 2.301881
# Epoch 48, loss: 2.302291
# Epoch 49, loss: 2.302069
# Epoch 50, loss: 2.301971
# Epoch 51, loss: 2.302533
# Epoch 52, loss: 2.302043
# Epoch 53, loss: 2.302003
# Epoch 54, loss: 2.301729
# Epoch 55, loss: 2.301272
# Epoch 56, loss: 2.302220
# Epoch 57, loss: 2.301765
# Epoch 58, loss: 2.301959
# Epoch 59, loss: 2.302229
# Epoch 60, loss: 2.301372
# Epoch 61, loss: 2.302540
# Epoch 62, loss: 2.301929
# Epoch 63, loss: 2.301502
# Epoch 64, loss: 2.302201
# Epoch 65, loss: 2.302674
# Epoch 66, loss: 2.302191
# Epoch 67, loss: 2.302989
# Epoch 68, loss: 2.301388
# Epoch 69, loss: 2.301621
# Epoch 70, loss: 2.301533
# Epoch 71, loss: 2.302804
# Epoch 72, loss: 2.301514
# Epoch 73, loss: 2.300962
# Epoch 74, loss: 2.302366
# Epoch 75, loss: 2.301895
# Epoch 76, loss: 2.301768
# Epoch 77, loss: 2.302649
# Epoch 78, loss: 2.302394
# Epoch 79, loss: 2.301415
# Epoch 80, loss: 2.302148
# Epoch 81, loss: 2.302263
# Epoch 82, loss: 2.301172
# Epoch 83, loss: 2.302803
# Epoch 84, loss: 2.301892
# Epoch 85, loss: 2.302788
# Epoch 86, loss: 2.302016
# Epoch 87, loss: 2.302450
# Epoch 88, loss: 2.302002
# Epoch 89, loss: 2.302363
# Epoch 90, loss: 2.301257
# Epoch 91, loss: 2.302553
# Epoch 92, loss: 2.301951
# Epoch 93, loss: 2.300910
# Epoch 94, loss: 2.302318
# Epoch 95, loss: 2.301563
# Epoch 96, loss: 2.302494
# Epoch 97, loss: 2.301579
# Epoch 98, loss: 2.302468
# Epoch 99, loss: 2.302352
# Accuracy after training for 100 epochs:  0.121

# %% [markdown]
# ### Как и раньше, используем кросс-валидацию для подбора гиперпараметтов.
#
# В этот раз, чтобы тренировка занимала разумное время, мы будем использовать только одно разделение на тренировочные (training) и проверочные (validation) данные.
#
# Теперь нам нужно подобрать не один, а два гиперпараметра! Не ограничивайте себя изначальными значениями в коде.
# Добейтесь точности более чем **20%** на проверочных данных (validation data).

# %%
num_epochs = 200
batch_size = 300

learning_rates = [1e-3, 1e-4, 1e-5]
reg_strengths = [1e-4, 1e-5, 1e-6]

best_classifier = None
best_val_accuracy = None

# TODO use validation set to find the best hyperparameters
# hint: for best results, you might need to try more values for learning rate and regularization strength 
# than provided initially
for lRate in learning_rates:
    for rStrength in reg_strengths:
        loss_history = classifier.fit(train_X, train_y, epochs=num_epochs, learning_rate=lRate, batch_size=batch_size, reg=rStrength)
        pred = classifier.predict(val_X)
        accuracy = multiclass_accuracy(pred, val_y)
        if best_val_accuracy is None or best_val_accuracy < accuracy:
            best_classifier = classifier
            best_val_accuracy = accuracy


print('best validation accuracy achieved: %f' % best_val_accuracy)
# Out:
# Epoch 0, loss: 2.127402
# Epoch 1, loss: 2.143007
# Epoch 2, loss: 2.142685
# Epoch 3, loss: 2.154321
# Epoch 4, loss: 2.125005
# Epoch 5, loss: 2.174982
# Epoch 6, loss: 2.113251
# Epoch 7, loss: 2.151980
# Epoch 8, loss: 2.112294
# Epoch 9, loss: 2.131851
# Epoch 10, loss: 2.134624
# Epoch 11, loss: 2.156854
# Epoch 12, loss: 2.177571
# Epoch 13, loss: 2.107094
# Epoch 14, loss: 2.155640
# Epoch 15, loss: 2.191139
# Epoch 16, loss: 2.095332
# Epoch 17, loss: 2.163954
# Epoch 18, loss: 2.161150
# Epoch 19, loss: 2.144372
# Epoch 20, loss: 2.169569
# Epoch 21, loss: 2.121763
# Epoch 22, loss: 2.115318
# Epoch 23, loss: 2.177579
# Epoch 24, loss: 2.172549
# Epoch 25, loss: 2.149077
# Epoch 26, loss: 2.185822
# Epoch 27, loss: 2.184980
# Epoch 28, loss: 2.127951
# Epoch 29, loss: 2.121759
# Epoch 30, loss: 2.121203
# Epoch 31, loss: 2.141930
# Epoch 32, loss: 2.136648
# Epoch 33, loss: 2.188269
# Epoch 34, loss: 2.120776
# Epoch 35, loss: 2.132027
# Epoch 36, loss: 2.153817
# Epoch 37, loss: 2.164341
# Epoch 38, loss: 2.146384
# Epoch 39, loss: 2.094683
# Epoch 40, loss: 2.176356
# Epoch 41, loss: 2.118480
# Epoch 42, loss: 2.189392
# Epoch 43, loss: 2.141095
# Epoch 44, loss: 2.119269
# Epoch 45, loss: 2.094835
# Epoch 46, loss: 2.142760
# Epoch 47, loss: 2.132773
# Epoch 48, loss: 2.121371
# Epoch 49, loss: 2.129463
# Epoch 50, loss: 2.151382
# Epoch 51, loss: 2.160582
# Epoch 52, loss: 2.129291
# Epoch 53, loss: 2.107668
# Epoch 54, loss: 2.151493
# Epoch 55, loss: 2.179673
# Epoch 56, loss: 2.120314
# Epoch 57, loss: 2.148632
# Epoch 58, loss: 2.143601
# Epoch 59, loss: 2.104836
# Epoch 60, loss: 2.139228
# Epoch 61, loss: 2.150305
# Epoch 62, loss: 2.144393
# Epoch 63, loss: 2.159840
# Epoch 64, loss: 2.125224
# Epoch 65, loss: 2.172642
# Epoch 66, loss: 2.120021
# Epoch 67, loss: 2.161151
# Epoch 68, loss: 2.156893
# Epoch 69, loss: 2.128467
# Epoch 70, loss: 2.113245
# Epoch 71, loss: 2.170540
# Epoch 72, loss: 2.133061
# Epoch 73, loss: 2.126352
# Epoch 74, loss: 2.109577
# Epoch 75, loss: 2.119519
# Epoch 76, loss: 2.172238
# Epoch 77, loss: 2.109667
# Epoch 78, loss: 2.144689
# Epoch 79, loss: 2.127899
# Epoch 80, loss: 2.153060
# Epoch 81, loss: 2.102971
# Epoch 82, loss: 2.137164
# Epoch 83, loss: 2.150472
# Epoch 84, loss: 2.122579
# Epoch 85, loss: 2.164110
# Epoch 86, loss: 2.153476
# Epoch 87, loss: 2.153805
# Epoch 88, loss: 2.160850
# Epoch 89, loss: 2.084417
# Epoch 90, loss: 2.178254
# Epoch 91, loss: 2.148715
# Epoch 92, loss: 2.104340
# Epoch 93, loss: 2.107978
# Epoch 94, loss: 2.179319
# Epoch 95, loss: 2.073994
# Epoch 96, loss: 2.107621
# Epoch 97, loss: 2.122838
# Epoch 98, loss: 2.135256
# Epoch 99, loss: 2.104584
# Epoch 100, loss: 2.128677
# Epoch 101, loss: 2.103875
# Epoch 102, loss: 2.154689
# Epoch 103, loss: 2.097805
# Epoch 104, loss: 2.134347
# Epoch 105, loss: 2.095620
# Epoch 106, loss: 2.184351
# Epoch 107, loss: 2.142457
# Epoch 108, loss: 2.138710
# Epoch 109, loss: 2.197689
# Epoch 110, loss: 2.131850
# Epoch 111, loss: 2.157964
# Epoch 112, loss: 2.118895
# Epoch 113, loss: 2.093373
# Epoch 114, loss: 2.161796
# Epoch 115, loss: 2.158971
# Epoch 116, loss: 2.152727
# Epoch 117, loss: 2.121005
# Epoch 118, loss: 2.112355
# Epoch 119, loss: 2.138024
# Epoch 120, loss: 2.084953
# Epoch 121, loss: 2.147965
# Epoch 122, loss: 2.117201
# Epoch 123, loss: 2.134252
# Epoch 124, loss: 2.175695
# Epoch 125, loss: 2.172892
# Epoch 126, loss: 2.086488
# Epoch 127, loss: 2.191674
# Epoch 128, loss: 2.169981
# Epoch 129, loss: 2.131891
# Epoch 130, loss: 2.147676
# Epoch 131, loss: 2.087548
# Epoch 132, loss: 2.125317
# Epoch 133, loss: 2.105823
# Epoch 134, loss: 2.142177
# Epoch 135, loss: 2.109667
# Epoch 136, loss: 2.116716
# Epoch 137, loss: 2.126850
# Epoch 138, loss: 2.141786
# Epoch 139, loss: 2.152267
# Epoch 140, loss: 2.134418
# Epoch 141, loss: 2.139907
# Epoch 142, loss: 2.147199
# Epoch 143, loss: 2.134958
# Epoch 144, loss: 2.160708
# Epoch 145, loss: 2.114833
# Epoch 146, loss: 2.125493
# Epoch 147, loss: 2.162524
# Epoch 148, loss: 2.151647
# Epoch 149, loss: 2.214874
# Epoch 150, loss: 2.230281
# Epoch 151, loss: 2.150185
# Epoch 152, loss: 2.110870
# Epoch 153, loss: 2.155538
# Epoch 154, loss: 2.197949
# Epoch 155, loss: 2.210207
# Epoch 156, loss: 2.086708
# Epoch 157, loss: 2.192163
# Epoch 158, loss: 2.153234
# Epoch 159, loss: 2.116413
# Epoch 160, loss: 2.122505
# Epoch 161, loss: 2.193149
# Epoch 162, loss: 2.102698
# Epoch 163, loss: 2.167876
# Epoch 164, loss: 2.128189
# Epoch 165, loss: 2.136915
# Epoch 166, loss: 2.168271
# Epoch 167, loss: 2.086838
# Epoch 168, loss: 2.133119
# Epoch 169, loss: 2.100038
# Epoch 170, loss: 2.161982
# Epoch 171, loss: 2.103092
# Epoch 172, loss: 2.112967
# Epoch 173, loss: 2.153983
# Epoch 174, loss: 2.155990
# Epoch 175, loss: 2.125217
# Epoch 176, loss: 2.157515
# Epoch 177, loss: 2.131528
# Epoch 178, loss: 2.097838
# Epoch 179, loss: 2.163605
# Epoch 180, loss: 2.104841
# Epoch 181, loss: 2.144319
# Epoch 182, loss: 2.138118
# Epoch 183, loss: 2.134204
# Epoch 184, loss: 2.164834
# Epoch 185, loss: 2.139837
# Epoch 186, loss: 2.125405
# Epoch 187, loss: 2.103779
# Epoch 188, loss: 2.094868
# Epoch 189, loss: 2.134648
# Epoch 190, loss: 2.147530
# Epoch 191, loss: 2.095410
# Epoch 192, loss: 2.143809
# Epoch 193, loss: 2.128673
# Epoch 194, loss: 2.149238
# Epoch 195, loss: 2.095866
# Epoch 196, loss: 2.164689
# Epoch 197, loss: 2.134017
# Epoch 198, loss: 2.139034
# Epoch 199, loss: 2.179330
# Epoch 0, loss: 2.102077
# Epoch 1, loss: 2.154565
# Epoch 2, loss: 2.130871
# Epoch 3, loss: 2.221103
# Epoch 4, loss: 2.082523
# Epoch 5, loss: 2.062925
# Epoch 6, loss: 2.145116
# Epoch 7, loss: 2.092220
# Epoch 8, loss: 2.125545
# Epoch 9, loss: 2.084178
# Epoch 10, loss: 2.122566
# Epoch 11, loss: 2.149825
# Epoch 12, loss: 2.130286
# Epoch 13, loss: 2.128783
# Epoch 14, loss: 2.142864
# Epoch 15, loss: 2.118728
# Epoch 16, loss: 2.158079
# Epoch 17, loss: 2.098006
# Epoch 18, loss: 2.124885
# Epoch 19, loss: 2.125769
# Epoch 20, loss: 2.136239
# Epoch 21, loss: 2.105299
# Epoch 22, loss: 2.121905
# Epoch 23, loss: 2.118429
# Epoch 24, loss: 2.150256
# Epoch 25, loss: 2.097594
# Epoch 26, loss: 2.167058
# Epoch 27, loss: 2.171287
# Epoch 28, loss: 2.135402
# Epoch 29, loss: 2.101942
# Epoch 30, loss: 2.133537
# Epoch 31, loss: 2.111805
# Epoch 32, loss: 2.078671
# Epoch 33, loss: 2.083543
# Epoch 34, loss: 2.112711
# Epoch 35, loss: 2.132960
# Epoch 36, loss: 2.132391
# Epoch 37, loss: 2.128389
# Epoch 38, loss: 2.130511
# Epoch 39, loss: 2.136965
# Epoch 40, loss: 2.142262
# Epoch 41, loss: 2.155372
# Epoch 42, loss: 2.150767
# Epoch 43, loss: 2.131881
# Epoch 44, loss: 2.108079
# Epoch 45, loss: 2.184114
# Epoch 46, loss: 2.147619
# Epoch 47, loss: 2.201963
# Epoch 48, loss: 2.184656
# Epoch 49, loss: 2.127792
# Epoch 50, loss: 2.093176
# Epoch 51, loss: 2.179875
# Epoch 52, loss: 2.109004
# Epoch 53, loss: 2.098073
# Epoch 54, loss: 2.151282
# Epoch 55, loss: 2.103846
# Epoch 56, loss: 2.078417
# Epoch 57, loss: 2.140230
# Epoch 58, loss: 2.139149
# Epoch 59, loss: 2.156089
# Epoch 60, loss: 2.162481
# Epoch 61, loss: 2.148823
# Epoch 62, loss: 2.104179
# Epoch 63, loss: 2.098505
# Epoch 64, loss: 2.080467
# Epoch 65, loss: 2.131670
# Epoch 66, loss: 2.092894
# Epoch 67, loss: 2.125951
# Epoch 68, loss: 2.126349
# Epoch 69, loss: 2.167353
# Epoch 70, loss: 2.166574
# Epoch 71, loss: 2.116889
# Epoch 72, loss: 2.112768
# Epoch 73, loss: 2.149488
# Epoch 74, loss: 2.155074
# Epoch 75, loss: 2.132715
# Epoch 76, loss: 2.133364
# Epoch 77, loss: 2.135544
# Epoch 78, loss: 2.064944
# Epoch 79, loss: 2.118573
# Epoch 80, loss: 2.111374
# Epoch 81, loss: 2.132621
# Epoch 82, loss: 2.059204
# Epoch 83, loss: 2.143844
# Epoch 84, loss: 2.156360
# Epoch 85, loss: 2.087635
# Epoch 86, loss: 2.089072
# Epoch 87, loss: 2.142167
# Epoch 88, loss: 2.119208
# Epoch 89, loss: 2.141623
# Epoch 90, loss: 2.119504
# Epoch 91, loss: 2.125167
# Epoch 92, loss: 2.107669
# Epoch 93, loss: 2.116683
# Epoch 94, loss: 2.103279
# Epoch 95, loss: 2.109155
# Epoch 96, loss: 2.097368
# Epoch 97, loss: 2.187731
# Epoch 98, loss: 2.152735
# Epoch 99, loss: 2.074530
# Epoch 100, loss: 2.141935
# Epoch 101, loss: 2.147922
# Epoch 102, loss: 2.136238
# Epoch 103, loss: 2.152688
# Epoch 104, loss: 2.099452
# Epoch 105, loss: 2.157231
# Epoch 106, loss: 2.160754
# Epoch 107, loss: 2.147507
# Epoch 108, loss: 2.113504
# Epoch 109, loss: 2.109933
# Epoch 110, loss: 2.108750
# Epoch 111, loss: 2.076720
# Epoch 112, loss: 2.102286
# Epoch 113, loss: 2.160630
# Epoch 114, loss: 2.188281
# Epoch 115, loss: 2.070937
# Epoch 116, loss: 2.129913
# Epoch 117, loss: 2.085655
# Epoch 118, loss: 2.108057
# Epoch 119, loss: 2.127489
# Epoch 120, loss: 2.097404
# Epoch 121, loss: 2.135689
# Epoch 122, loss: 2.115578
# Epoch 123, loss: 2.143143
# Epoch 124, loss: 2.076656
# Epoch 125, loss: 2.117143
# Epoch 126, loss: 2.188656
# Epoch 127, loss: 2.089002
# Epoch 128, loss: 2.144185
# Epoch 129, loss: 2.046172
# Epoch 130, loss: 2.110547
# Epoch 131, loss: 2.086016
# Epoch 132, loss: 2.124203
# Epoch 133, loss: 2.104534
# Epoch 134, loss: 2.073420
# Epoch 135, loss: 2.070673
# Epoch 136, loss: 2.156875
# Epoch 137, loss: 2.131888
# Epoch 138, loss: 2.133994
# Epoch 139, loss: 2.134165
# Epoch 140, loss: 2.130714
# Epoch 141, loss: 2.144187
# Epoch 142, loss: 2.115512
# Epoch 143, loss: 2.148007
# Epoch 144, loss: 2.174481
# Epoch 145, loss: 2.134074
# Epoch 146, loss: 2.134188
# Epoch 147, loss: 2.076670
# Epoch 148, loss: 2.147608
# Epoch 149, loss: 2.169996
# Epoch 150, loss: 2.101204
# Epoch 151, loss: 2.101571
# Epoch 152, loss: 2.146687
# Epoch 153, loss: 2.105963
# Epoch 154, loss: 2.102343
# Epoch 155, loss: 2.088661
# Epoch 156, loss: 2.107624
# Epoch 157, loss: 2.130927
# Epoch 158, loss: 2.119596
# Epoch 159, loss: 2.162812
# Epoch 160, loss: 2.115544
# Epoch 161, loss: 2.105235
# Epoch 162, loss: 2.169385
# Epoch 163, loss: 2.154093
# Epoch 164, loss: 2.134209
# Epoch 165, loss: 2.063723
# Epoch 166, loss: 2.123464
# Epoch 167, loss: 2.125581
# Epoch 168, loss: 2.080120
# Epoch 169, loss: 2.154200
# Epoch 170, loss: 2.130448
# Epoch 171, loss: 2.121828
# Epoch 172, loss: 2.116544
# Epoch 173, loss: 2.088587
# Epoch 174, loss: 2.123008
# Epoch 175, loss: 2.110104
# Epoch 176, loss: 2.124563
# Epoch 177, loss: 2.146959
# Epoch 178, loss: 2.095459
# Epoch 179, loss: 2.177075
# Epoch 180, loss: 2.155150
# Epoch 181, loss: 2.090854
# Epoch 182, loss: 2.165531
# Epoch 183, loss: 2.118529
# Epoch 184, loss: 2.094851
# Epoch 185, loss: 2.104576
# Epoch 186, loss: 2.208246
# Epoch 187, loss: 2.141306
# Epoch 188, loss: 2.145859
# Epoch 189, loss: 2.093664
# Epoch 190, loss: 2.101690
# Epoch 191, loss: 2.150639
# Epoch 192, loss: 2.117871
# Epoch 193, loss: 2.058277
# Epoch 194, loss: 2.124682
# Epoch 195, loss: 2.099592
# Epoch 196, loss: 2.119768
# Epoch 197, loss: 2.098428
# Epoch 198, loss: 2.142096
# Epoch 199, loss: 2.153727
# Epoch 0, loss: 2.143881
# Epoch 1, loss: 2.126662
# Epoch 2, loss: 2.114023
# Epoch 3, loss: 2.171196
# Epoch 4, loss: 2.129176
# Epoch 5, loss: 2.163475
# Epoch 6, loss: 2.146984
# Epoch 7, loss: 2.100313
# Epoch 8, loss: 2.194432
# Epoch 9, loss: 2.148718
# Epoch 10, loss: 2.056180
# Epoch 11, loss: 2.146502
# Epoch 12, loss: 2.099391
# Epoch 13, loss: 2.136757
# Epoch 14, loss: 2.099771
# Epoch 15, loss: 2.115658
# Epoch 16, loss: 2.121138
# Epoch 17, loss: 2.129537
# Epoch 18, loss: 2.154260
# Epoch 19, loss: 2.118875
# Epoch 20, loss: 2.147765
# Epoch 21, loss: 2.136613
# Epoch 22, loss: 2.105807
# Epoch 23, loss: 2.093395
# Epoch 24, loss: 2.158457
# Epoch 25, loss: 2.108144
# Epoch 26, loss: 2.121328
# Epoch 27, loss: 2.077468
# Epoch 28, loss: 2.156496
# Epoch 29, loss: 2.164597
# Epoch 30, loss: 2.104782
# Epoch 31, loss: 2.105804
# Epoch 32, loss: 2.146643
# Epoch 33, loss: 2.142209
# Epoch 34, loss: 2.130642
# Epoch 35, loss: 2.121306
# Epoch 36, loss: 2.130468
# Epoch 37, loss: 2.116263
# Epoch 38, loss: 2.116316
# Epoch 39, loss: 2.137033
# Epoch 40, loss: 2.144501
# Epoch 41, loss: 2.100917
# Epoch 42, loss: 2.093403
# Epoch 43, loss: 2.171203
# Epoch 44, loss: 2.155336
# Epoch 45, loss: 2.108448
# Epoch 46, loss: 2.169668
# Epoch 47, loss: 2.136823
# Epoch 48, loss: 2.109032
# Epoch 49, loss: 2.117925
# Epoch 50, loss: 2.144362
# Epoch 51, loss: 2.071856
# Epoch 52, loss: 2.099637
# Epoch 53, loss: 2.115380
# Epoch 54, loss: 2.128743
# Epoch 55, loss: 2.059741
# Epoch 56, loss: 2.150752
# Epoch 57, loss: 2.109132
# Epoch 58, loss: 2.102244
# Epoch 59, loss: 2.114794
# Epoch 60, loss: 2.060425
# Epoch 61, loss: 2.079433
# Epoch 62, loss: 2.135101
# Epoch 63, loss: 2.128248
# Epoch 64, loss: 2.130212
# Epoch 65, loss: 2.123058
# Epoch 66, loss: 2.139326
# Epoch 67, loss: 2.112215
# Epoch 68, loss: 2.088774
# Epoch 69, loss: 2.108849
# Epoch 70, loss: 2.124807
# Epoch 71, loss: 2.160163
# Epoch 72, loss: 2.120479
# Epoch 73, loss: 2.165259
# Epoch 74, loss: 2.125514
# Epoch 75, loss: 2.106230
# Epoch 76, loss: 2.156601
# Epoch 77, loss: 2.126213
# Epoch 78, loss: 2.104989
# Epoch 79, loss: 2.134651
# Epoch 80, loss: 2.137193
# Epoch 81, loss: 2.148404
# Epoch 82, loss: 2.109876
# Epoch 83, loss: 2.131266
# Epoch 84, loss: 2.109295
# Epoch 85, loss: 2.167236
# Epoch 86, loss: 2.154018
# Epoch 87, loss: 2.123051
# Epoch 88, loss: 2.189910
# Epoch 89, loss: 2.154115
# Epoch 90, loss: 2.100004
# Epoch 91, loss: 2.105572
# Epoch 92, loss: 2.168691
# Epoch 93, loss: 2.054339
# Epoch 94, loss: 2.097859
# Epoch 95, loss: 2.125359
# Epoch 96, loss: 2.151872
# Epoch 97, loss: 2.123367
# Epoch 98, loss: 2.121619
# Epoch 99, loss: 2.118265
# Epoch 100, loss: 2.098346
# Epoch 101, loss: 2.089643
# Epoch 102, loss: 2.095692
# Epoch 103, loss: 2.126205
# Epoch 104, loss: 2.123991
# Epoch 105, loss: 2.127667
# Epoch 106, loss: 2.102727
# Epoch 107, loss: 2.132982
# Epoch 108, loss: 2.085163
# Epoch 109, loss: 2.110596
# Epoch 110, loss: 2.123327
# Epoch 111, loss: 2.145748
# Epoch 112, loss: 2.123558
# Epoch 113, loss: 2.142412
# Epoch 114, loss: 2.094999
# Epoch 115, loss: 2.173084
# Epoch 116, loss: 2.176679
# Epoch 117, loss: 2.111413
# Epoch 118, loss: 2.100151
# Epoch 119, loss: 2.092350
# Epoch 120, loss: 2.071337
# Epoch 121, loss: 2.107452
# Epoch 122, loss: 2.136449
# Epoch 123, loss: 2.164743
# Epoch 124, loss: 2.134792
# Epoch 125, loss: 2.149984
# Epoch 126, loss: 2.110970
# Epoch 127, loss: 2.105580
# Epoch 128, loss: 2.081905
# Epoch 129, loss: 2.089464
# Epoch 130, loss: 2.082361
# Epoch 131, loss: 2.109613
# Epoch 132, loss: 2.071593
# Epoch 133, loss: 2.169276
# Epoch 134, loss: 2.178769
# Epoch 135, loss: 2.154757
# Epoch 136, loss: 2.147303
# Epoch 137, loss: 2.081512
# Epoch 138, loss: 2.058582
# Epoch 139, loss: 2.147448
# Epoch 140, loss: 2.203397
# Epoch 141, loss: 2.144037
# Epoch 142, loss: 2.111194
# Epoch 143, loss: 2.133474
# Epoch 144, loss: 2.102154
# Epoch 145, loss: 2.209714
# Epoch 146, loss: 2.121581
# Epoch 147, loss: 2.160156
# Epoch 148, loss: 2.164644
# Epoch 149, loss: 2.186886
# Epoch 150, loss: 2.115303
# Epoch 151, loss: 2.096179
# Epoch 152, loss: 2.095685
# Epoch 153, loss: 2.121514
# Epoch 154, loss: 2.162893
# Epoch 155, loss: 2.156531
# Epoch 156, loss: 2.158827
# Epoch 157, loss: 2.137263
# Epoch 158, loss: 2.094989
# Epoch 159, loss: 2.169222
# Epoch 160, loss: 2.172580
# Epoch 161, loss: 2.154372
# Epoch 162, loss: 2.078828
# Epoch 163, loss: 2.117691
# Epoch 164, loss: 2.059839
# Epoch 165, loss: 2.073642
# Epoch 166, loss: 2.123629
# Epoch 167, loss: 2.134660
# Epoch 168, loss: 2.103818
# Epoch 169, loss: 2.186991
# Epoch 170, loss: 2.075544
# Epoch 171, loss: 2.137043
# Epoch 172, loss: 2.107734
# Epoch 173, loss: 2.104200
# Epoch 174, loss: 2.070760
# Epoch 175, loss: 2.144873
# Epoch 176, loss: 2.092720
# Epoch 177, loss: 2.059129
# Epoch 178, loss: 2.102992
# Epoch 179, loss: 2.086118
# Epoch 180, loss: 2.100715
# Epoch 181, loss: 2.122673
# Epoch 182, loss: 2.158750
# Epoch 183, loss: 2.125602
# Epoch 184, loss: 2.101453
# Epoch 185, loss: 2.119385
# Epoch 186, loss: 2.158791
# Epoch 187, loss: 2.095890
# Epoch 188, loss: 2.129560
# Epoch 189, loss: 2.120146
# Epoch 190, loss: 2.143058
# Epoch 191, loss: 2.115853
# Epoch 192, loss: 2.068769
# Epoch 193, loss: 2.141949
# Epoch 194, loss: 2.060213
# Epoch 195, loss: 2.059095
# Epoch 196, loss: 2.069493
# Epoch 197, loss: 2.062511
# Epoch 198, loss: 2.117474
# Epoch 199, loss: 2.106781
# Epoch 0, loss: 2.097356
# Epoch 1, loss: 2.067712
# Epoch 2, loss: 2.126773
# Epoch 3, loss: 2.118414
# Epoch 4, loss: 2.134704
# Epoch 5, loss: 2.128235
# Epoch 6, loss: 2.139368
# Epoch 7, loss: 2.101513
# Epoch 8, loss: 2.121879
# Epoch 9, loss: 2.113728
# Epoch 10, loss: 2.087482
# Epoch 11, loss: 2.102474
# Epoch 12, loss: 2.104869
# Epoch 13, loss: 2.106720
# Epoch 14, loss: 2.142515
# Epoch 15, loss: 2.100791
# Epoch 16, loss: 2.122164
# Epoch 17, loss: 2.121886
# Epoch 18, loss: 2.131598
# Epoch 19, loss: 2.100740
# Epoch 20, loss: 2.138565
# Epoch 21, loss: 2.185913
# Epoch 22, loss: 2.156408
# Epoch 23, loss: 2.134729
# Epoch 24, loss: 2.106001
# Epoch 25, loss: 2.107993
# Epoch 26, loss: 2.076675
# Epoch 27, loss: 2.118678
# Epoch 28, loss: 2.106701
# Epoch 29, loss: 2.115266
# Epoch 30, loss: 2.029507
# Epoch 31, loss: 2.091013
# Epoch 32, loss: 2.082736
# Epoch 33, loss: 2.114196
# Epoch 34, loss: 2.156564
# Epoch 35, loss: 2.149579
# Epoch 36, loss: 2.104358
# Epoch 37, loss: 2.095971
# Epoch 38, loss: 2.098075
# Epoch 39, loss: 2.091902
# Epoch 40, loss: 2.151177
# Epoch 41, loss: 2.154762
# Epoch 42, loss: 2.117614
# Epoch 43, loss: 2.102731
# Epoch 44, loss: 2.127915
# Epoch 45, loss: 2.108658
# Epoch 46, loss: 2.070960
# Epoch 47, loss: 2.067928
# Epoch 48, loss: 2.114607
# Epoch 49, loss: 2.168238
# Epoch 50, loss: 2.112175
# Epoch 51, loss: 2.111296
# Epoch 52, loss: 2.103708
# Epoch 53, loss: 2.113085
# Epoch 54, loss: 2.170435
# Epoch 55, loss: 2.157726
# Epoch 56, loss: 2.099390
# Epoch 57, loss: 2.111063
# Epoch 58, loss: 2.113070
# Epoch 59, loss: 2.070683
# Epoch 60, loss: 2.182209
# Epoch 61, loss: 2.096514
# Epoch 62, loss: 2.096645
# Epoch 63, loss: 2.114450
# Epoch 64, loss: 2.086615
# Epoch 65, loss: 2.149906
# Epoch 66, loss: 2.146896
# Epoch 67, loss: 2.128928
# Epoch 68, loss: 2.135973
# Epoch 69, loss: 2.090266
# Epoch 70, loss: 2.099995
# Epoch 71, loss: 2.183776
# Epoch 72, loss: 2.101104
# Epoch 73, loss: 2.103285
# Epoch 74, loss: 2.115370
# Epoch 75, loss: 2.133743
# Epoch 76, loss: 2.123717
# Epoch 77, loss: 2.079612
# Epoch 78, loss: 2.086576
# Epoch 79, loss: 2.099443
# Epoch 80, loss: 2.112594
# Epoch 81, loss: 2.077046
# Epoch 82, loss: 2.130675
# Epoch 83, loss: 2.060063
# Epoch 84, loss: 2.094262
# Epoch 85, loss: 2.135255
# Epoch 86, loss: 2.108145
# Epoch 87, loss: 2.107242
# Epoch 88, loss: 2.079476
# Epoch 89, loss: 2.105711
# Epoch 90, loss: 2.123160
# Epoch 91, loss: 2.097231
# Epoch 92, loss: 2.130806
# Epoch 93, loss: 2.117239
# Epoch 94, loss: 2.119486
# Epoch 95, loss: 2.084141
# Epoch 96, loss: 2.071855
# Epoch 97, loss: 2.107650
# Epoch 98, loss: 2.129946
# Epoch 99, loss: 2.113120
# Epoch 100, loss: 2.165328
# Epoch 101, loss: 2.086074
# Epoch 102, loss: 2.063751
# Epoch 103, loss: 2.138210
# Epoch 104, loss: 2.111659
# Epoch 105, loss: 2.135288
# Epoch 106, loss: 2.130505
# Epoch 107, loss: 2.105836
# Epoch 108, loss: 2.131467
# Epoch 109, loss: 2.103508
# Epoch 110, loss: 2.064792
# Epoch 111, loss: 2.118769
# Epoch 112, loss: 2.126447
# Epoch 113, loss: 2.026179
# Epoch 114, loss: 2.113872
# Epoch 115, loss: 2.157623
# Epoch 116, loss: 2.126854
# Epoch 117, loss: 2.113009
# Epoch 118, loss: 2.049026
# Epoch 119, loss: 2.110260
# Epoch 120, loss: 2.099657
# Epoch 121, loss: 2.137888
# Epoch 122, loss: 2.158018
# Epoch 123, loss: 2.100438
# Epoch 124, loss: 2.126644
# Epoch 125, loss: 2.193134
# Epoch 126, loss: 2.135350
# Epoch 127, loss: 2.176244
# Epoch 128, loss: 2.128457
# Epoch 129, loss: 2.120588
# Epoch 130, loss: 2.104067
# Epoch 131, loss: 2.157885
# Epoch 132, loss: 2.117970
# Epoch 133, loss: 2.135655
# Epoch 134, loss: 2.088261
# Epoch 135, loss: 2.059988
# Epoch 136, loss: 2.142604
# Epoch 137, loss: 2.101285
# Epoch 138, loss: 2.106799
# Epoch 139, loss: 2.135898
# Epoch 140, loss: 2.173170
# Epoch 141, loss: 2.131710
# Epoch 142, loss: 2.171949
# Epoch 143, loss: 2.134417
# Epoch 144, loss: 2.083573
# Epoch 145, loss: 2.067670
# Epoch 146, loss: 2.110141
# Epoch 147, loss: 2.140048
# Epoch 148, loss: 2.106828
# Epoch 149, loss: 2.072538
# Epoch 150, loss: 2.087971
# Epoch 151, loss: 2.173515
# Epoch 152, loss: 2.145097
# Epoch 153, loss: 2.119606
# Epoch 154, loss: 2.116910
# Epoch 155, loss: 2.119621
# Epoch 156, loss: 2.162013
# Epoch 157, loss: 2.140662
# Epoch 158, loss: 2.180671
# Epoch 159, loss: 2.103298
# Epoch 160, loss: 2.114093
# Epoch 161, loss: 2.100865
# Epoch 162, loss: 2.092186
# Epoch 163, loss: 2.082308
# Epoch 164, loss: 2.127892
# Epoch 165, loss: 2.072434
# Epoch 166, loss: 2.142984
# Epoch 167, loss: 2.085355
# Epoch 168, loss: 2.086392
# Epoch 169, loss: 2.112134
# Epoch 170, loss: 2.128808
# Epoch 171, loss: 2.147054
# Epoch 172, loss: 2.141318
# Epoch 173, loss: 2.094268
# Epoch 174, loss: 2.132725
# Epoch 175, loss: 2.115922
# Epoch 176, loss: 2.120107
# Epoch 177, loss: 2.118812
# Epoch 178, loss: 2.081357
# Epoch 179, loss: 2.112160
# Epoch 180, loss: 2.113812
# Epoch 181, loss: 2.160326
# Epoch 182, loss: 2.079659
# Epoch 183, loss: 2.156099
# Epoch 184, loss: 2.104846
# Epoch 185, loss: 2.148046
# Epoch 186, loss: 2.085550
# Epoch 187, loss: 2.116629
# Epoch 188, loss: 2.187693
# Epoch 189, loss: 2.154724
# Epoch 190, loss: 2.141108
# Epoch 191, loss: 2.137281
# Epoch 192, loss: 2.091528
# Epoch 193, loss: 2.133927
# Epoch 194, loss: 2.093882
# Epoch 195, loss: 2.091921
# Epoch 196, loss: 2.107668
# Epoch 197, loss: 2.079267
# Epoch 198, loss: 2.152642
# Epoch 199, loss: 2.068995
# Epoch 0, loss: 2.161549
# Epoch 1, loss: 2.063922
# Epoch 2, loss: 2.124205
# Epoch 3, loss: 2.144211
# Epoch 4, loss: 2.094226
# Epoch 5, loss: 2.135775
# Epoch 6, loss: 2.121930
# Epoch 7, loss: 2.185055
# Epoch 8, loss: 2.139581
# Epoch 9, loss: 2.130343
# Epoch 10, loss: 2.127961
# Epoch 11, loss: 2.107208
# Epoch 12, loss: 2.082053
# Epoch 13, loss: 2.109381
# Epoch 14, loss: 2.119415
# Epoch 15, loss: 2.088998
# Epoch 16, loss: 2.100379
# Epoch 17, loss: 2.122908
# Epoch 18, loss: 2.085404
# Epoch 19, loss: 2.151416
# Epoch 20, loss: 2.151101
# Epoch 21, loss: 2.062660
# Epoch 22, loss: 2.032838
# Epoch 23, loss: 2.123898
# Epoch 24, loss: 2.144226
# Epoch 25, loss: 2.115960
# Epoch 26, loss: 2.118872
# Epoch 27, loss: 2.115104
# Epoch 28, loss: 2.119534
# Epoch 29, loss: 2.127616
# Epoch 30, loss: 2.099452
# Epoch 31, loss: 2.135088
# Epoch 32, loss: 2.157286
# Epoch 33, loss: 2.127260
# Epoch 34, loss: 2.115696
# Epoch 35, loss: 2.117024
# Epoch 36, loss: 2.097342
# Epoch 37, loss: 2.115402
# Epoch 38, loss: 2.172075
# Epoch 39, loss: 2.116232
# Epoch 40, loss: 2.169229
# Epoch 41, loss: 2.084187
# Epoch 42, loss: 2.105935
# Epoch 43, loss: 2.124354
# Epoch 44, loss: 2.149897
# Epoch 45, loss: 2.071793
# Epoch 46, loss: 2.128970
# Epoch 47, loss: 2.094924
# Epoch 48, loss: 2.142909
# Epoch 49, loss: 2.099214
# Epoch 50, loss: 2.114650
# Epoch 51, loss: 2.112779
# Epoch 52, loss: 2.151315
# Epoch 53, loss: 2.130647
# Epoch 54, loss: 2.089534
# Epoch 55, loss: 2.169956
# Epoch 56, loss: 2.109875
# Epoch 57, loss: 2.080314
# Epoch 58, loss: 2.129314
# Epoch 59, loss: 2.152879
# Epoch 60, loss: 2.072749
# Epoch 61, loss: 2.138110
# Epoch 62, loss: 2.116703
# Epoch 63, loss: 2.117779
# Epoch 64, loss: 2.103252
# Epoch 65, loss: 2.142986
# Epoch 66, loss: 2.111372
# Epoch 67, loss: 2.141354
# Epoch 68, loss: 2.134707
# Epoch 69, loss: 2.155252
# Epoch 70, loss: 2.187577
# Epoch 71, loss: 2.154606
# Epoch 72, loss: 2.137934
# Epoch 73, loss: 2.081361
# Epoch 74, loss: 2.110053
# Epoch 75, loss: 2.118876
# Epoch 76, loss: 2.080672
# Epoch 77, loss: 2.155829
# Epoch 78, loss: 2.129506
# Epoch 79, loss: 2.111225
# Epoch 80, loss: 2.079099
# Epoch 81, loss: 2.097333
# Epoch 82, loss: 2.081315
# Epoch 83, loss: 2.102897
# Epoch 84, loss: 2.104545
# Epoch 85, loss: 2.127359
# Epoch 86, loss: 2.101423
# Epoch 87, loss: 2.149700
# Epoch 88, loss: 2.100859
# Epoch 89, loss: 2.164859
# Epoch 90, loss: 2.147287
# Epoch 91, loss: 2.092108
# Epoch 92, loss: 2.123353
# Epoch 93, loss: 2.105662
# Epoch 94, loss: 2.083795
# Epoch 95, loss: 2.132172
# Epoch 96, loss: 2.142496
# Epoch 97, loss: 2.106179
# Epoch 98, loss: 2.164476
# Epoch 99, loss: 2.077426
# Epoch 100, loss: 2.101056
# Epoch 101, loss: 2.119459
# Epoch 102, loss: 2.107647
# Epoch 103, loss: 2.142427
# Epoch 104, loss: 2.098441
# Epoch 105, loss: 2.094411
# Epoch 106, loss: 2.111557
# Epoch 107, loss: 2.136963
# Epoch 108, loss: 2.141637
# Epoch 109, loss: 2.141545
# Epoch 110, loss: 2.142407
# Epoch 111, loss: 2.136378
# Epoch 112, loss: 2.068672
# Epoch 113, loss: 2.100859
# Epoch 114, loss: 2.088252
# Epoch 115, loss: 2.075957
# Epoch 116, loss: 2.149000
# Epoch 117, loss: 2.109966
# Epoch 118, loss: 2.136072
# Epoch 119, loss: 2.169388
# Epoch 120, loss: 2.116395
# Epoch 121, loss: 2.119240
# Epoch 122, loss: 2.176469
# Epoch 123, loss: 2.119103
# Epoch 124, loss: 2.097638
# Epoch 125, loss: 2.100343
# Epoch 126, loss: 2.108790
# Epoch 127, loss: 2.128486
# Epoch 128, loss: 2.099260
# Epoch 129, loss: 2.132704
# Epoch 130, loss: 2.151300
# Epoch 131, loss: 2.121123
# Epoch 132, loss: 2.140341
# Epoch 133, loss: 2.076990
# Epoch 134, loss: 2.075037
# Epoch 135, loss: 2.113151
# Epoch 136, loss: 2.107995
# Epoch 137, loss: 2.126249
# Epoch 138, loss: 2.053943
# Epoch 139, loss: 2.109906
# Epoch 140, loss: 2.088797
# Epoch 141, loss: 2.123728
# Epoch 142, loss: 2.133319
# Epoch 143, loss: 2.103117
# Epoch 144, loss: 2.082323
# Epoch 145, loss: 2.124145
# Epoch 146, loss: 2.113898
# Epoch 147, loss: 2.156171
# Epoch 148, loss: 2.085105
# Epoch 149, loss: 2.095934
# Epoch 150, loss: 2.065359
# Epoch 151, loss: 2.125441
# Epoch 152, loss: 2.147655
# Epoch 153, loss: 2.115474
# Epoch 154, loss: 2.096080
# Epoch 155, loss: 2.125378
# Epoch 156, loss: 2.133804
# Epoch 157, loss: 2.161450
# Epoch 158, loss: 2.150274
# Epoch 159, loss: 2.108597
# Epoch 160, loss: 2.125625
# Epoch 161, loss: 2.074364
# Epoch 162, loss: 2.084865
# Epoch 163, loss: 2.116537
# Epoch 164, loss: 2.162537
# Epoch 165, loss: 2.143355
# Epoch 166, loss: 2.105988
# Epoch 167, loss: 2.076996
# Epoch 168, loss: 2.128232
# Epoch 169, loss: 2.142787
# Epoch 170, loss: 2.135394
# Epoch 171, loss: 2.112732
# Epoch 172, loss: 2.124663
# Epoch 173, loss: 2.119583
# Epoch 174, loss: 2.119706
# Epoch 175, loss: 2.120083
# Epoch 176, loss: 2.154264
# Epoch 177, loss: 2.113124
# Epoch 178, loss: 2.101001
# Epoch 179, loss: 2.113323
# Epoch 180, loss: 2.107136
# Epoch 181, loss: 2.099808
# Epoch 182, loss: 2.065497
# Epoch 183, loss: 2.058847
# Epoch 184, loss: 2.129381
# Epoch 185, loss: 2.113168
# Epoch 186, loss: 2.086634
# Epoch 187, loss: 2.122942
# Epoch 188, loss: 2.048329
# Epoch 189, loss: 2.135120
# Epoch 190, loss: 2.094063
# Epoch 191, loss: 2.136340
# Epoch 192, loss: 2.088518
# Epoch 193, loss: 2.112964
# Epoch 194, loss: 2.095354
# Epoch 195, loss: 2.144973
# Epoch 196, loss: 2.076562
# Epoch 197, loss: 2.127212
# Epoch 198, loss: 2.133306
# Epoch 199, loss: 2.112530
# Epoch 0, loss: 2.124710
# Epoch 1, loss: 2.109417
# Epoch 2, loss: 2.118892
# Epoch 3, loss: 2.108855
# Epoch 4, loss: 2.194511
# Epoch 5, loss: 2.142388
# Epoch 6, loss: 2.114412
# Epoch 7, loss: 2.118173
# Epoch 8, loss: 2.072146
# Epoch 9, loss: 2.176105
# Epoch 10, loss: 2.166332
# Epoch 11, loss: 2.054597
# Epoch 12, loss: 2.090536
# Epoch 13, loss: 2.093917
# Epoch 14, loss: 2.113782
# Epoch 15, loss: 2.116543
# Epoch 16, loss: 2.118153
# Epoch 17, loss: 2.072267
# Epoch 18, loss: 2.083213
# Epoch 19, loss: 2.131672
# Epoch 20, loss: 2.134862
# Epoch 21, loss: 2.097971
# Epoch 22, loss: 2.121400
# Epoch 23, loss: 2.164780
# Epoch 24, loss: 2.118913
# Epoch 25, loss: 2.119841
# Epoch 26, loss: 2.109950
# Epoch 27, loss: 2.096367
# Epoch 28, loss: 2.161075
# Epoch 29, loss: 2.087956
# Epoch 30, loss: 2.113408
# Epoch 31, loss: 2.166402
# Epoch 32, loss: 2.116586
# Epoch 33, loss: 2.171828
# Epoch 34, loss: 2.114442
# Epoch 35, loss: 2.149732
# Epoch 36, loss: 2.090035
# Epoch 37, loss: 2.133178
# Epoch 38, loss: 2.106452
# Epoch 39, loss: 2.094258
# Epoch 40, loss: 2.107788
# Epoch 41, loss: 2.131085
# Epoch 42, loss: 2.161932
# Epoch 43, loss: 2.187487
# Epoch 44, loss: 2.158688
# Epoch 45, loss: 2.076854
# Epoch 46, loss: 2.089091
# Epoch 47, loss: 2.076957
# Epoch 48, loss: 2.099965
# Epoch 49, loss: 2.112628
# Epoch 50, loss: 2.110760
# Epoch 51, loss: 2.108240
# Epoch 52, loss: 2.151506
# Epoch 53, loss: 2.145057
# Epoch 54, loss: 2.123110
# Epoch 55, loss: 2.067770
# Epoch 56, loss: 2.107789
# Epoch 57, loss: 2.146879
# Epoch 58, loss: 2.095574
# Epoch 59, loss: 2.153408
# Epoch 60, loss: 2.109719
# Epoch 61, loss: 2.069808
# Epoch 62, loss: 2.111211
# Epoch 63, loss: 2.066825
# Epoch 64, loss: 2.102962
# Epoch 65, loss: 2.125071
# Epoch 66, loss: 2.147960
# Epoch 67, loss: 2.128214
# Epoch 68, loss: 2.099142
# Epoch 69, loss: 2.143880
# Epoch 70, loss: 2.111803
# Epoch 71, loss: 2.105445
# Epoch 72, loss: 2.167862
# Epoch 73, loss: 2.102453
# Epoch 74, loss: 2.180921
# Epoch 75, loss: 2.123969
# Epoch 76, loss: 2.103608
# Epoch 77, loss: 2.150439
# Epoch 78, loss: 2.118937
# Epoch 79, loss: 2.130498
# Epoch 80, loss: 2.091623
# Epoch 81, loss: 2.106603
# Epoch 82, loss: 2.140120
# Epoch 83, loss: 2.129998
# Epoch 84, loss: 2.136260
# Epoch 85, loss: 2.115883
# Epoch 86, loss: 2.115123
# Epoch 87, loss: 2.146841
# Epoch 88, loss: 2.063459
# Epoch 89, loss: 2.133633
# Epoch 90, loss: 2.099675
# Epoch 91, loss: 2.121638
# Epoch 92, loss: 2.126733
# Epoch 93, loss: 2.123072
# Epoch 94, loss: 2.092159
# Epoch 95, loss: 2.103627
# Epoch 96, loss: 2.080261
# Epoch 97, loss: 2.126808
# Epoch 98, loss: 2.095885
# Epoch 99, loss: 2.117209
# Epoch 100, loss: 2.135652
# Epoch 101, loss: 2.106284
# Epoch 102, loss: 2.136554
# Epoch 103, loss: 2.096864
# Epoch 104, loss: 2.084178
# Epoch 105, loss: 2.132322
# Epoch 106, loss: 2.121617
# Epoch 107, loss: 2.108308
# Epoch 108, loss: 2.130960
# Epoch 109, loss: 2.065587
# Epoch 110, loss: 2.146744
# Epoch 111, loss: 2.133462
# Epoch 112, loss: 2.133776
# Epoch 113, loss: 2.126021
# Epoch 114, loss: 2.121572
# Epoch 115, loss: 2.104844
# Epoch 116, loss: 2.115790
# Epoch 117, loss: 2.098258
# Epoch 118, loss: 2.098136
# Epoch 119, loss: 2.126429
# Epoch 120, loss: 2.093227
# Epoch 121, loss: 2.120809
# Epoch 122, loss: 2.113567
# Epoch 123, loss: 2.141194
# Epoch 124, loss: 2.127191
# Epoch 125, loss: 2.130270
# Epoch 126, loss: 2.137972
# Epoch 127, loss: 2.102892
# Epoch 128, loss: 2.055247
# Epoch 129, loss: 2.127068
# Epoch 130, loss: 2.114516
# Epoch 131, loss: 2.107262
# Epoch 132, loss: 2.090258
# Epoch 133, loss: 2.077419
# Epoch 134, loss: 2.119737
# Epoch 135, loss: 2.156631
# Epoch 136, loss: 2.124679
# Epoch 137, loss: 2.078039
# Epoch 138, loss: 2.116782
# Epoch 139, loss: 2.143947
# Epoch 140, loss: 2.163320
# Epoch 141, loss: 2.117227
# Epoch 142, loss: 2.129076
# Epoch 143, loss: 2.032335
# Epoch 144, loss: 2.054459
# Epoch 145, loss: 2.129919
# Epoch 146, loss: 2.097413
# Epoch 147, loss: 2.158567
# Epoch 148, loss: 2.127798
# Epoch 149, loss: 2.135486
# Epoch 150, loss: 2.102547
# Epoch 151, loss: 2.102246
# Epoch 152, loss: 2.124888
# Epoch 153, loss: 2.131346
# Epoch 154, loss: 2.134231
# Epoch 155, loss: 2.164905
# Epoch 156, loss: 2.147011
# Epoch 157, loss: 2.139429
# Epoch 158, loss: 2.107617
# Epoch 159, loss: 2.128288
# Epoch 160, loss: 2.110371
# Epoch 161, loss: 2.086007
# Epoch 162, loss: 2.136799
# Epoch 163, loss: 2.178748
# Epoch 164, loss: 2.089972
# Epoch 165, loss: 2.108453
# Epoch 166, loss: 2.103621
# Epoch 167, loss: 2.175186
# Epoch 168, loss: 2.112748
# Epoch 169, loss: 2.084386
# Epoch 170, loss: 2.109180
# Epoch 171, loss: 2.134764
# Epoch 172, loss: 2.107780
# Epoch 173, loss: 2.117783
# Epoch 174, loss: 2.151385
# Epoch 175, loss: 2.118684
# Epoch 176, loss: 2.094714
# Epoch 177, loss: 2.170337
# Epoch 178, loss: 2.080850
# Epoch 179, loss: 2.186737
# Epoch 180, loss: 2.160179
# Epoch 181, loss: 2.124742
# Epoch 182, loss: 2.155237
# Epoch 183, loss: 2.117547
# Epoch 184, loss: 2.169775
# Epoch 185, loss: 2.052221
# Epoch 186, loss: 2.063461
# Epoch 187, loss: 2.137046
# Epoch 188, loss: 2.170768
# Epoch 189, loss: 2.129037
# Epoch 190, loss: 2.111374
# Epoch 191, loss: 2.166270
# Epoch 192, loss: 2.105343
# Epoch 193, loss: 2.095398
# Epoch 194, loss: 2.060681
# Epoch 195, loss: 2.104703
# Epoch 196, loss: 2.083709
# Epoch 197, loss: 2.199905
# Epoch 198, loss: 2.144614
# Epoch 199, loss: 2.124750
# Epoch 0, loss: 2.155324
# Epoch 1, loss: 2.157664
# Epoch 2, loss: 2.114252
# Epoch 3, loss: 2.116201
# Epoch 4, loss: 2.093190
# Epoch 5, loss: 2.075104
# Epoch 6, loss: 2.117324
# Epoch 7, loss: 2.137870
# Epoch 8, loss: 2.112998
# Epoch 9, loss: 2.044074
# Epoch 10, loss: 2.137566
# Epoch 11, loss: 2.139544
# Epoch 12, loss: 2.142129
# Epoch 13, loss: 2.104384
# Epoch 14, loss: 2.111706
# Epoch 15, loss: 2.123268
# Epoch 16, loss: 2.110428
# Epoch 17, loss: 2.123028
# Epoch 18, loss: 2.118466
# Epoch 19, loss: 2.138608
# Epoch 20, loss: 2.103841
# Epoch 21, loss: 2.119132
# Epoch 22, loss: 2.095345
# Epoch 23, loss: 2.119197
# Epoch 24, loss: 2.117479
# Epoch 25, loss: 2.095067
# Epoch 26, loss: 2.111738
# Epoch 27, loss: 2.079724
# Epoch 28, loss: 2.133332
# Epoch 29, loss: 2.101796
# Epoch 30, loss: 2.179871
# Epoch 31, loss: 2.054994
# Epoch 32, loss: 2.083200
# Epoch 33, loss: 2.092840
# Epoch 34, loss: 2.133894
# Epoch 35, loss: 2.099236
# Epoch 36, loss: 2.151975
# Epoch 37, loss: 2.129811
# Epoch 38, loss: 2.122303
# Epoch 39, loss: 2.047376
# Epoch 40, loss: 2.141551
# Epoch 41, loss: 2.072126
# Epoch 42, loss: 2.104679
# Epoch 43, loss: 2.111620
# Epoch 44, loss: 2.080460
# Epoch 45, loss: 2.108018
# Epoch 46, loss: 2.032289
# Epoch 47, loss: 2.106519
# Epoch 48, loss: 2.112733
# Epoch 49, loss: 2.184694
# Epoch 50, loss: 2.134827
# Epoch 51, loss: 2.121705
# Epoch 52, loss: 2.095534
# Epoch 53, loss: 2.126181
# Epoch 54, loss: 2.155983
# Epoch 55, loss: 2.107895
# Epoch 56, loss: 2.070860
# Epoch 57, loss: 2.133248
# Epoch 58, loss: 2.106868
# Epoch 59, loss: 2.125138
# Epoch 60, loss: 2.081687
# Epoch 61, loss: 2.129480
# Epoch 62, loss: 2.081436
# Epoch 63, loss: 2.142437
# Epoch 64, loss: 2.087268
# Epoch 65, loss: 2.145194
# Epoch 66, loss: 2.087666
# Epoch 67, loss: 2.108769
# Epoch 68, loss: 2.179276
# Epoch 69, loss: 2.058681
# Epoch 70, loss: 2.076665
# Epoch 71, loss: 2.137187
# Epoch 72, loss: 2.122151
# Epoch 73, loss: 2.131939
# Epoch 74, loss: 2.057206
# Epoch 75, loss: 2.148477
# Epoch 76, loss: 2.078127
# Epoch 77, loss: 2.072823
# Epoch 78, loss: 2.109947
# Epoch 79, loss: 2.102685
# Epoch 80, loss: 2.090988
# Epoch 81, loss: 2.121819
# Epoch 82, loss: 2.102748
# Epoch 83, loss: 2.141931
# Epoch 84, loss: 2.077411
# Epoch 85, loss: 2.136911
# Epoch 86, loss: 2.076930
# Epoch 87, loss: 2.142560
# Epoch 88, loss: 2.176293
# Epoch 89, loss: 2.129312
# Epoch 90, loss: 2.136667
# Epoch 91, loss: 2.060836
# Epoch 92, loss: 2.103594
# Epoch 93, loss: 2.137665
# Epoch 94, loss: 2.172669
# Epoch 95, loss: 2.078851
# Epoch 96, loss: 2.164482
# Epoch 97, loss: 2.147331
# Epoch 98, loss: 2.138167
# Epoch 99, loss: 2.145038
# Epoch 100, loss: 2.128443
# Epoch 101, loss: 2.128087
# Epoch 102, loss: 2.130231
# Epoch 103, loss: 2.094097
# Epoch 104, loss: 2.118537
# Epoch 105, loss: 2.044132
# Epoch 106, loss: 2.128056
# Epoch 107, loss: 2.124682
# Epoch 108, loss: 2.120830
# Epoch 109, loss: 2.142283
# Epoch 110, loss: 2.117397
# Epoch 111, loss: 2.133660
# Epoch 112, loss: 2.119942
# Epoch 113, loss: 2.129087
# Epoch 114, loss: 2.104900
# Epoch 115, loss: 2.108126
# Epoch 116, loss: 2.121407
# Epoch 117, loss: 2.117276
# Epoch 118, loss: 2.099938
# Epoch 119, loss: 2.125059
# Epoch 120, loss: 2.184779
# Epoch 121, loss: 2.092381
# Epoch 122, loss: 2.135523
# Epoch 123, loss: 2.123179
# Epoch 124, loss: 2.065596
# Epoch 125, loss: 2.091842
# Epoch 126, loss: 2.113981
# Epoch 127, loss: 2.105796
# Epoch 128, loss: 2.055873
# Epoch 129, loss: 2.080190
# Epoch 130, loss: 2.080995
# Epoch 131, loss: 2.130860
# Epoch 132, loss: 2.134091
# Epoch 133, loss: 2.102841
# Epoch 134, loss: 2.057367
# Epoch 135, loss: 2.083680
# Epoch 136, loss: 2.164742
# Epoch 137, loss: 2.123125
# Epoch 138, loss: 2.123941
# Epoch 139, loss: 2.102700
# Epoch 140, loss: 2.113924
# Epoch 141, loss: 2.103067
# Epoch 142, loss: 2.153147
# Epoch 143, loss: 2.117323
# Epoch 144, loss: 2.087814
# Epoch 145, loss: 2.125354
# Epoch 146, loss: 2.090291
# Epoch 147, loss: 2.130291
# Epoch 148, loss: 2.110500
# Epoch 149, loss: 2.093482
# Epoch 150, loss: 2.148629
# Epoch 151, loss: 2.112500
# Epoch 152, loss: 2.147658
# Epoch 153, loss: 2.089252
# Epoch 154, loss: 2.129730
# Epoch 155, loss: 2.137152
# Epoch 156, loss: 2.109166
# Epoch 157, loss: 2.121330
# Epoch 158, loss: 2.130375
# Epoch 159, loss: 2.080887
# Epoch 160, loss: 2.139248
# Epoch 161, loss: 2.056876
# Epoch 162, loss: 2.115049
# Epoch 163, loss: 2.121552
# Epoch 164, loss: 2.114706
# Epoch 165, loss: 2.106234
# Epoch 166, loss: 2.115732
# Epoch 167, loss: 2.127502
# Epoch 168, loss: 2.152453
# Epoch 169, loss: 2.101170
# Epoch 170, loss: 2.092521
# Epoch 171, loss: 2.109871
# Epoch 172, loss: 2.080464
# Epoch 173, loss: 2.130307
# Epoch 174, loss: 2.089020
# Epoch 175, loss: 2.096431
# Epoch 176, loss: 2.105522
# Epoch 177, loss: 2.146339
# Epoch 178, loss: 2.128972
# Epoch 179, loss: 2.134368
# Epoch 180, loss: 2.129615
# Epoch 181, loss: 2.094271
# Epoch 182, loss: 2.061529
# Epoch 183, loss: 2.157654
# Epoch 184, loss: 2.096887
# Epoch 185, loss: 2.116970
# Epoch 186, loss: 2.103475
# Epoch 187, loss: 2.125485
# Epoch 188, loss: 2.080086
# Epoch 189, loss: 2.125079
# Epoch 190, loss: 2.070552
# Epoch 191, loss: 2.140072
# Epoch 192, loss: 2.132444
# Epoch 193, loss: 2.116770
# Epoch 194, loss: 2.067113
# Epoch 195, loss: 2.143006
# Epoch 196, loss: 2.125695
# Epoch 197, loss: 2.112688
# Epoch 198, loss: 2.075628
# Epoch 199, loss: 2.093735
# Epoch 0, loss: 2.145450
# Epoch 1, loss: 2.121758
# Epoch 2, loss: 2.127289
# Epoch 3, loss: 2.109237
# Epoch 4, loss: 2.132641
# Epoch 5, loss: 2.158484
# Epoch 6, loss: 2.081712
# Epoch 7, loss: 2.131157
# Epoch 8, loss: 2.116375
# Epoch 9, loss: 2.139609
# Epoch 10, loss: 2.124112
# Epoch 11, loss: 2.116110
# Epoch 12, loss: 2.109146
# Epoch 13, loss: 2.062977
# Epoch 14, loss: 2.119826
# Epoch 15, loss: 2.134439
# Epoch 16, loss: 2.142250
# Epoch 17, loss: 2.127410
# Epoch 18, loss: 2.115597
# Epoch 19, loss: 2.094530
# Epoch 20, loss: 2.112731
# Epoch 21, loss: 2.139861
# Epoch 22, loss: 2.076826
# Epoch 23, loss: 2.137086
# Epoch 24, loss: 2.106571
# Epoch 25, loss: 2.155766
# Epoch 26, loss: 2.083225
# Epoch 27, loss: 2.102101
# Epoch 28, loss: 2.107339
# Epoch 29, loss: 2.073049
# Epoch 30, loss: 2.100904
# Epoch 31, loss: 2.201898
# Epoch 32, loss: 2.097539
# Epoch 33, loss: 2.126530
# Epoch 34, loss: 2.095772
# Epoch 35, loss: 2.112060
# Epoch 36, loss: 2.139952
# Epoch 37, loss: 2.131131
# Epoch 38, loss: 2.110892
# Epoch 39, loss: 2.116471
# Epoch 40, loss: 2.108486
# Epoch 41, loss: 2.132550
# Epoch 42, loss: 2.119087
# Epoch 43, loss: 2.089364
# Epoch 44, loss: 2.114187
# Epoch 45, loss: 2.153365
# Epoch 46, loss: 2.071644
# Epoch 47, loss: 2.132849
# Epoch 48, loss: 2.091966
# Epoch 49, loss: 2.150175
# Epoch 50, loss: 2.122137
# Epoch 51, loss: 2.166494
# Epoch 52, loss: 2.068672
# Epoch 53, loss: 2.095891
# Epoch 54, loss: 2.071274
# Epoch 55, loss: 2.092087
# Epoch 56, loss: 2.075780
# Epoch 57, loss: 2.111664
# Epoch 58, loss: 2.136775
# Epoch 59, loss: 2.112919
# Epoch 60, loss: 2.108162
# Epoch 61, loss: 2.115560
# Epoch 62, loss: 2.027774
# Epoch 63, loss: 2.136615
# Epoch 64, loss: 2.058928
# Epoch 65, loss: 2.177378
# Epoch 66, loss: 2.073064
# Epoch 67, loss: 2.111613
# Epoch 68, loss: 2.163934
# Epoch 69, loss: 2.110785
# Epoch 70, loss: 2.155329
# Epoch 71, loss: 2.157352
# Epoch 72, loss: 2.128780
# Epoch 73, loss: 2.106774
# Epoch 74, loss: 2.141099
# Epoch 75, loss: 2.134914
# Epoch 76, loss: 2.145408
# Epoch 77, loss: 2.074078
# Epoch 78, loss: 2.131082
# Epoch 79, loss: 2.172448
# Epoch 80, loss: 2.112143
# Epoch 81, loss: 2.173897
# Epoch 82, loss: 2.104300
# Epoch 83, loss: 2.114457
# Epoch 84, loss: 2.121968
# Epoch 85, loss: 2.092575
# Epoch 86, loss: 2.092209
# Epoch 87, loss: 2.108493
# Epoch 88, loss: 2.134807
# Epoch 89, loss: 2.124712
# Epoch 90, loss: 2.075193
# Epoch 91, loss: 2.142331
# Epoch 92, loss: 2.107050
# Epoch 93, loss: 2.129196
# Epoch 94, loss: 2.088297
# Epoch 95, loss: 2.151678
# Epoch 96, loss: 2.106268
# Epoch 97, loss: 2.122755
# Epoch 98, loss: 2.160766
# Epoch 99, loss: 2.080568
# Epoch 100, loss: 2.085529
# Epoch 101, loss: 2.168570
# Epoch 102, loss: 2.123182
# Epoch 103, loss: 2.081315
# Epoch 104, loss: 2.083994
# Epoch 105, loss: 2.077483
# Epoch 106, loss: 2.169812
# Epoch 107, loss: 2.140692
# Epoch 108, loss: 2.135784
# Epoch 109, loss: 2.162566
# Epoch 110, loss: 2.134221
# Epoch 111, loss: 2.126040
# Epoch 112, loss: 2.137349
# Epoch 113, loss: 2.144241
# Epoch 114, loss: 2.048625
# Epoch 115, loss: 2.085565
# Epoch 116, loss: 2.088205
# Epoch 117, loss: 2.131015
# Epoch 118, loss: 2.046319
# Epoch 119, loss: 2.128070
# Epoch 120, loss: 2.110307
# Epoch 121, loss: 2.102106
# Epoch 122, loss: 2.095559
# Epoch 123, loss: 2.083948
# Epoch 124, loss: 2.083635
# Epoch 125, loss: 2.130748
# Epoch 126, loss: 2.054149
# Epoch 127, loss: 2.141401
# Epoch 128, loss: 2.105600
# Epoch 129, loss: 2.097251
# Epoch 130, loss: 2.080678
# Epoch 131, loss: 2.120547
# Epoch 132, loss: 2.147928
# Epoch 133, loss: 2.111195
# Epoch 134, loss: 2.152802
# Epoch 135, loss: 2.079952
# Epoch 136, loss: 2.088857
# Epoch 137, loss: 2.141856
# Epoch 138, loss: 2.060505
# Epoch 139, loss: 2.121293
# Epoch 140, loss: 2.153708
# Epoch 141, loss: 2.081824
# Epoch 142, loss: 2.116105
# Epoch 143, loss: 2.093194
# Epoch 144, loss: 2.145768
# Epoch 145, loss: 2.109399
# Epoch 146, loss: 2.110847
# Epoch 147, loss: 2.144127
# Epoch 148, loss: 2.119924
# Epoch 149, loss: 2.152351
# Epoch 150, loss: 2.137617
# Epoch 151, loss: 2.080234
# Epoch 152, loss: 2.081151
# Epoch 153, loss: 2.157051
# Epoch 154, loss: 2.108421
# Epoch 155, loss: 2.142392
# Epoch 156, loss: 2.112985
# Epoch 157, loss: 2.099711
# Epoch 158, loss: 2.133232
# Epoch 159, loss: 2.100542
# Epoch 160, loss: 2.075598
# Epoch 161, loss: 2.092401
# Epoch 162, loss: 2.168456
# Epoch 163, loss: 2.110046
# Epoch 164, loss: 2.118499
# Epoch 165, loss: 2.095424
# Epoch 166, loss: 2.056101
# Epoch 167, loss: 2.115106
# Epoch 168, loss: 2.087543
# Epoch 169, loss: 2.097415
# Epoch 170, loss: 2.118982
# Epoch 171, loss: 2.075504
# Epoch 172, loss: 2.156597
# Epoch 173, loss: 2.100920
# Epoch 174, loss: 2.115493
# Epoch 175, loss: 2.110675
# Epoch 176, loss: 2.098895
# Epoch 177, loss: 2.072911
# Epoch 178, loss: 2.157444
# Epoch 179, loss: 2.152358
# Epoch 180, loss: 2.089374
# Epoch 181, loss: 2.077808
# Epoch 182, loss: 2.115286
# Epoch 183, loss: 2.070233
# Epoch 184, loss: 2.133909
# Epoch 185, loss: 2.155958
# Epoch 186, loss: 2.095495
# Epoch 187, loss: 2.155521
# Epoch 188, loss: 2.188194
# Epoch 189, loss: 2.112722
# Epoch 190, loss: 2.095852
# Epoch 191, loss: 2.109268
# Epoch 192, loss: 2.084772
# Epoch 193, loss: 2.105191
# Epoch 194, loss: 2.121669
# Epoch 195, loss: 2.117517
# Epoch 196, loss: 2.143142
# Epoch 197, loss: 2.083162
# Epoch 198, loss: 2.142631
# Epoch 199, loss: 2.129608
# Epoch 0, loss: 2.102364
# Epoch 1, loss: 2.067028
# Epoch 2, loss: 2.165362
# Epoch 3, loss: 2.054226
# Epoch 4, loss: 2.072986
# Epoch 5, loss: 2.096762
# Epoch 6, loss: 2.135605
# Epoch 7, loss: 2.098093
# Epoch 8, loss: 2.150338
# Epoch 9, loss: 2.125174
# Epoch 10, loss: 2.121354
# Epoch 11, loss: 2.181078
# Epoch 12, loss: 2.038699
# Epoch 13, loss: 2.074652
# Epoch 14, loss: 2.081481
# Epoch 15, loss: 2.123558
# Epoch 16, loss: 2.106009
# Epoch 17, loss: 2.084109
# Epoch 18, loss: 2.084159
# Epoch 19, loss: 2.140742
# Epoch 20, loss: 2.132140
# Epoch 21, loss: 2.095996
# Epoch 22, loss: 2.155118
# Epoch 23, loss: 2.084776
# Epoch 24, loss: 2.108631
# Epoch 25, loss: 2.116808
# Epoch 26, loss: 2.080110
# Epoch 27, loss: 2.078785
# Epoch 28, loss: 2.146929
# Epoch 29, loss: 2.112326
# Epoch 30, loss: 2.117133
# Epoch 31, loss: 2.094347
# Epoch 32, loss: 2.096932
# Epoch 33, loss: 2.134350
# Epoch 34, loss: 2.089814
# Epoch 35, loss: 2.102121
# Epoch 36, loss: 2.070074
# Epoch 37, loss: 2.119310
# Epoch 38, loss: 2.103231
# Epoch 39, loss: 2.101988
# Epoch 40, loss: 2.055905
# Epoch 41, loss: 2.080989
# Epoch 42, loss: 2.129452
# Epoch 43, loss: 2.137347
# Epoch 44, loss: 2.065322
# Epoch 45, loss: 2.099315
# Epoch 46, loss: 2.108687
# Epoch 47, loss: 2.175331
# Epoch 48, loss: 2.111464
# Epoch 49, loss: 2.092459
# Epoch 50, loss: 2.125629
# Epoch 51, loss: 2.167415
# Epoch 52, loss: 2.162977
# Epoch 53, loss: 2.082645
# Epoch 54, loss: 2.083941
# Epoch 55, loss: 2.108414
# Epoch 56, loss: 2.103734
# Epoch 57, loss: 2.128921
# Epoch 58, loss: 2.063042
# Epoch 59, loss: 2.147820
# Epoch 60, loss: 2.117850
# Epoch 61, loss: 2.128996
# Epoch 62, loss: 2.104014
# Epoch 63, loss: 2.122902
# Epoch 64, loss: 2.107420
# Epoch 65, loss: 2.130377
# Epoch 66, loss: 2.111811
# Epoch 67, loss: 2.113932
# Epoch 68, loss: 2.116940
# Epoch 69, loss: 2.045945
# Epoch 70, loss: 2.107783
# Epoch 71, loss: 2.108407
# Epoch 72, loss: 2.133209
# Epoch 73, loss: 2.134008
# Epoch 74, loss: 2.084095
# Epoch 75, loss: 2.107968
# Epoch 76, loss: 2.136846
# Epoch 77, loss: 2.145028
# Epoch 78, loss: 2.064403
# Epoch 79, loss: 2.104960
# Epoch 80, loss: 2.069526
# Epoch 81, loss: 2.140906
# Epoch 82, loss: 2.117560
# Epoch 83, loss: 2.154371
# Epoch 84, loss: 2.118650
# Epoch 85, loss: 2.098297
# Epoch 86, loss: 2.139676
# Epoch 87, loss: 2.145939
# Epoch 88, loss: 2.086692
# Epoch 89, loss: 2.110626
# Epoch 90, loss: 2.087077
# Epoch 91, loss: 2.140884
# Epoch 92, loss: 2.084405
# Epoch 93, loss: 2.146363
# Epoch 94, loss: 2.140129
# Epoch 95, loss: 2.120172
# Epoch 96, loss: 2.131976
# Epoch 97, loss: 2.108478
# Epoch 98, loss: 2.105851
# Epoch 99, loss: 2.121737
# Epoch 100, loss: 2.155210
# Epoch 101, loss: 2.125498
# Epoch 102, loss: 2.158958
# Epoch 103, loss: 2.077544
# Epoch 104, loss: 2.136525
# Epoch 105, loss: 2.108611
# Epoch 106, loss: 2.159393
# Epoch 107, loss: 2.178257
# Epoch 108, loss: 2.151326
# Epoch 109, loss: 2.103416
# Epoch 110, loss: 2.108542
# Epoch 111, loss: 2.144894
# Epoch 112, loss: 2.089802
# Epoch 113, loss: 2.117658
# Epoch 114, loss: 2.110632
# Epoch 115, loss: 2.072504
# Epoch 116, loss: 2.164407
# Epoch 117, loss: 2.118263
# Epoch 118, loss: 2.093089
# Epoch 119, loss: 2.084229
# Epoch 120, loss: 2.100155
# Epoch 121, loss: 2.096339
# Epoch 122, loss: 2.114354
# Epoch 123, loss: 2.163198
# Epoch 124, loss: 2.097263
# Epoch 125, loss: 2.138227
# Epoch 126, loss: 2.103925
# Epoch 127, loss: 2.132483
# Epoch 128, loss: 2.128692
# Epoch 129, loss: 2.147907
# Epoch 130, loss: 2.131250
# Epoch 131, loss: 2.095463
# Epoch 132, loss: 2.099291
# Epoch 133, loss: 2.116436
# Epoch 134, loss: 2.182196
# Epoch 135, loss: 2.168142
# Epoch 136, loss: 2.163372
# Epoch 137, loss: 2.136837
# Epoch 138, loss: 2.092396
# Epoch 139, loss: 2.123650
# Epoch 140, loss: 2.144123
# Epoch 141, loss: 2.106730
# Epoch 142, loss: 2.113106
# Epoch 143, loss: 2.173231
# Epoch 144, loss: 2.088804
# Epoch 145, loss: 2.112141
# Epoch 146, loss: 2.126174
# Epoch 147, loss: 2.160455
# Epoch 148, loss: 2.155215
# Epoch 149, loss: 2.156159
# Epoch 150, loss: 2.128678
# Epoch 151, loss: 2.097978
# Epoch 152, loss: 2.144178
# Epoch 153, loss: 2.165872
# Epoch 154, loss: 2.172725
# Epoch 155, loss: 2.102159
# Epoch 156, loss: 2.082832
# Epoch 157, loss: 2.161682
# Epoch 158, loss: 2.131862
# Epoch 159, loss: 2.151650
# Epoch 160, loss: 2.127836
# Epoch 161, loss: 2.070160
# Epoch 162, loss: 2.125546
# Epoch 163, loss: 2.125506
# Epoch 164, loss: 2.102251
# Epoch 165, loss: 2.159159
# Epoch 166, loss: 2.091714
# Epoch 167, loss: 2.111750
# Epoch 168, loss: 2.095514
# Epoch 169, loss: 2.104508
# Epoch 170, loss: 2.153926
# Epoch 171, loss: 2.141555
# Epoch 172, loss: 2.160789
# Epoch 173, loss: 2.083685
# Epoch 174, loss: 2.094379
# Epoch 175, loss: 2.086144
# Epoch 176, loss: 2.082697
# Epoch 177, loss: 2.109708
# Epoch 178, loss: 2.083515
# Epoch 179, loss: 2.055021
# Epoch 180, loss: 2.109415
# Epoch 181, loss: 2.075256
# Epoch 182, loss: 2.075882
# Epoch 183, loss: 2.108497
# Epoch 184, loss: 2.090344
# Epoch 185, loss: 2.100050
# Epoch 186, loss: 2.087619
# Epoch 187, loss: 2.158420
# Epoch 188, loss: 2.111365
# Epoch 189, loss: 2.101761
# Epoch 190, loss: 2.137061
# Epoch 191, loss: 2.101985
# Epoch 192, loss: 2.089437
# Epoch 193, loss: 2.075878
# Epoch 194, loss: 2.095878
# Epoch 195, loss: 2.105615
# Epoch 196, loss: 2.160888
# Epoch 197, loss: 2.077591
# Epoch 198, loss: 2.171547
# Epoch 199, loss: 2.107511
# best validation accuracy achieved: 0.249000

# %% [markdown]
# # Какой же точности мы добились на тестовых данных?

# %%
test_pred = best_classifier.predict(test_X)
test_accuracy = multiclass_accuracy(test_pred, test_y)
print('Linear softmax classifier test set accuracy: %f' % (test_accuracy, ))
